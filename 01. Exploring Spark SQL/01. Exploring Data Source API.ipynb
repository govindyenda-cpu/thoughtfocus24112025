# %% [markdown]
# #Create Dataframe

# %%
dfr= spark.read
# print(type(df))

# %% [markdown]
# #Create dataframe from different Sources
# ##   Create Dataframe from .csv

# %%
# csvdf=dfr.csv(path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_001.csv",header=True)
csvdf = spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_001.csv",
    header=True,inferSchema=True
)
# display(csvdf)
csvdf.printSchema()

# %% [markdown]
# ## Create Dataframe with  delimeted File

# %%
datdf = spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_001.dat",
    header=True,inferSchema=True,sep="|"
)
display(datdf)
datdf.printSchema()

# %% [markdown]
# ## Create Dataframe with  .json file

# %%
spark.read.json(path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_001.json").display()

# %% [markdown]
# ## MultiLine  enabler for  .json

# %%
spark.read.json(path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_002.json",multiLine=True).display()

# %% [markdown]
# ## Array of Json

# %%
spark.read.json(path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_004.json",multiLine=True).display()

# %% [markdown]
# ## Custom  Schema

# %%
from pyspark.sql.types import *
 
USER_SCHEMA = StructType(
    [
        StructField("id", IntegerType()),
        StructField("age", IntegerType()),
        StructField("gen", StringType()),
        StructField("designation", StringType()),
        StructField("salary", IntegerType()),
    ]
)
df = spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_001.csv",
    header=True,
    schema=USER_SCHEMA
)
# df.printSchema()
df.display()

# %% [markdown]
# ### ## Handling with bad Records
# 1.PERMISSIVE -- >Default -- >_corrupt_record
# 2.DROPMALFORMED
# 3.FAILFAST

# %%
spark.read.json(path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/access_logs.json",mode="PERMISSIVE").display()

# %%
spark.read.json(path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/access_logs.json",mode="DROPMALFORMED").display()

# %%
spark.read.json(path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/access_logs.json",mode="FAILFAST").display()
